# %%
import pandas as pd

# %%
df31 = pd.read_csv('/usr/local/home/ssbw5/classification/crnn/logs_ep1M/eval_history.csv')
df31.tail()
# Out:
#       epoch  train_loss  train_acc  val_loss   val_acc
# 4022   4022    0.159856        1.0  2.250621  0.770016
# 4023   4023    0.159856        1.0  2.264337  0.771091
# 4024   4024    0.159856        1.0  2.281070  0.774315
# 4025   4025    0.159856        1.0  2.259702  0.771628
# 4026   4026    0.159859        1.0  2.280054  0.774852

# %%
df31.plot(x = 'epoch',y = ['train_loss','val_loss'],figsize = (10,6))

# %%
df31.plot(x = 'epoch',y = ['train_acc','val_acc'],figsize = (10,6))
